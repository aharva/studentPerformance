# %% [markdown]
# ## Reading the file

# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['writing score'].median()
# Out:
# np.float64(69.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# ## FOR FINDING ONLY NO OF ROWS

# %%
df.shape[0]
# Out:
# 1000

# %% [markdown]
# FOR FINDING NULL VALUES

# %%
df.isnull().sum(axis=0)
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df[["math score"]].mean()
# Out:
# math score    66.089
# dtype: float64

# %%
df[['math score']].max()
# Out:
# math score    100
# dtype: int64

# %% [markdown]
# FOR MEDIAN I M DOING MEANS 50% FROM DESCRIBE FUNCTION WILL GET THE VALUE

# %%
df['math score'].median()
# Out:
# np.float64(66.0)

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# STORING TOTAL SCORE BY CREATING IT AND STORING EACH COLUMN MARKS INTO IT AND ADDING TO OUR datset

# %%
df["Total score"]=df['writing score']+df['reading score']+df['math score']
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df["Average score"]=df['Total score']/3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total score  Average score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
df['Total score'].head()
# Out:
# 0    218
# 1    247
# 2    278
# 3    148
# 4    229
# Name: Total score, dtype: int64

# %%
df['Average score'].head()
# Out:
# 0    72.666667
# 1    82.333333
# 2    92.666667
# 3    49.333333
# 4    76.333333
# Name: Average score, dtype: float64

# %% [markdown]
# FOR FINDING OUT THE MAX VALUE AT INDEX FROM THE CSV FILE

# %%
topper=df["Total score"].idxmax()
topper
# Out:
# 458

# %% [markdown]
# FOR FINDING THE ROW FOR THE TOPPER AND OTHER INFORMATION loc → Label-based indexing

# %%
df.loc[topper]
# Out:
# gender                                    female
# race/ethnicity                           group E
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                   100
# reading score                                100
# writing score                                100
# Total score                                  300
# Average score                              100.0
# Name: 458, dtype: object

# %% [markdown]
# iloc:integer based location ; gives same output as loc but just it gives o/p according to the integer index

# %%
df.iloc[topper]
# Out:
# gender                                    female
# race/ethnicity                           group E
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                   100
# reading score                                100
# writing score                                100
# Total score                                  300
# Average score                              100.0
# Name: 458, dtype: object

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Total score', 'Average score'],
#       dtype='object')

# %%
df['Total score'].sort_values(ascending=False).head()
# Out:
# 916    300
# 962    300
# 458    300
# 114    299
# 712    297
# Name: Total score, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Total score', 'Average score'],
#       dtype='object')

# %% [markdown]
# (Show failed students)

# %%
df[df['math score']<40]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 55   female        group C                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 61     male        group A            some high school  free/reduced
# 69   female        group C          associate's degree      standard
# 76     male        group E            some high school      standard
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 211    male        group C                some college  free/reduced
# 217  female        group C                 high school  free/reduced
# 284  female        group B            some high school      standard
# 327    male        group A                some college  free/reduced
# ...

# %% [markdown]
# Count failed students

# %%
df[df['math score']<40].shape[0]
# Out:
# 40

# %%
df[df['reading score']<40].shape[0]
# Out:
# 26
